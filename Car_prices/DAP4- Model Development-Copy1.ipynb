# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##  Important Variables for the study
#
# ###  Numeric variables: horsepower, engine size, highway-L/100km, city-L/100km, bore, curb weight, length, width, wheel base.
#
# ### Categorical variables: drive-wheels.

# %%
archive = "~/Documentos/Programación/Python/Data Science/automovil_clean.csv"
df = pd.read_csv(archive)

# %%
df1 = df[["horsepower", "engine-size", "highway-L/100km", "city-L/100km", "bore", "drive-wheels", "curb-weight","length","width","wheel-base","price"]]

# %%
# df.iloc[:,1].value_counts()
var_list = df1.columns.to_list()
Hp,ES,HL,CL,Br,DW,CW,L,W,WB = var_list[0],var_list[1],var_list[2],var_list[3],var_list[4],var_list[5],var_list[6],var_list[7],var_list[8],var_list[9]
price = var_list[10]

# %%
lm = LinearRegression()
X = df1[[HL]]
Y = df1[price]
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
yhat = lm.predict(X)
type(yhat)
print(Y[:3],"\n",yhat[:3])
# Out:
# 0    13495
# 1    16500
# 2    16500
# Name: price, dtype: int64
#  [15485.52737455 15485.52737455 16643.34931414]

# %%
print("b_0= ",lm.intercept_, "b_1 = ", lm.coef_ )
# Out:
# b_0=  -14617.843054664605 b_1 =  [2861.94014644]

# %%
sns.regplot( x = HL , y = price, data = df1)
plt.ylim(0,)
# Out:
# (0.0, 47714.101248781655)

# %%
sns.residplot( df1[HL], df1[price])
# Out:
# /home/rocko/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='highway-L/100km', ylabel='price'>

# %%
lm1 = LinearRegression()

# %%
lm1.fit(df1[[ES]],df1[price])
print("Intercept: ",lm1.intercept_,"\nSlope:", lm1.coef_)
# Out:
# Intercept:  -7963.338906281046
# Slope: [166.86001569]

# %% [markdown]
# $y_{hat} = -7963.34 + 166.86 * Engine Size  $

# %%
sns.regplot(ES, price, data = df1)
plt.ylim(0,)
# Out:
# /home/rocko/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 53292.98609938798)

# %%
sns.residplot(ES,price,data = df1)
# Out:
# /home/rocko/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='engine-size', ylabel='price'>

# %%
sns.regplot(Hp ,price, data = df1)
plt.ylim(0,)
# Out:
# (0.0, 47536.99434512558)

# %%
sns.residplot(Hp,price, data = df1)
# Out:
# /home/rocko/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='horsepower', ylabel='price'>

# %%
sns.regplot(CW,price, data = df1)
plt.ylim(0,)
# Out:
# (0.0, 47754.9903002783)

# %%
sns.residplot(CW,price,data = df1)
# Out:
# /home/rocko/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='curb-weight', ylabel='price'>

# %%
sns.regplot(CL,price,data = df1)
plt.ylim(0,)
# Out:
# (0.0, 47726.907359168305)

# %%
sns.residplot(CL,price, data = df1)
# Out:
# /home/rocko/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='city-L/100km', ylabel='price'>

# %%
X1 = df1[[Hp,CW,Br,L,W]]
lm2 = LinearRegression()
lm2.fit(X1,df1[price])
# Out:
# LinearRegression()

# %%
print("Intercept: ",lm2.intercept_,"\nSlope:", lm2.coef_)
# Out:
# Intercept:  -53510.41273293279
# Slope: [ 8.91814482e+01  6.88287297e+00 -9.70232199e+02 -1.65195066e+04
#   6.22489818e+04]

# %%
y_hat = lm2.predict(X1)

# %%
HL,CL,Br,DW,L,W,WB

# %%
sns.regplot(df1[Br], df1[price], data = df1)
plt.ylim(0,)
# Out:
# /home/rocko/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 47799.53326053778)

# %%
sns.residplot(df1[Br], df1[price], data = df1)
# Out:
# /home/rocko/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bore', ylabel='price'>

# %%
sns.regplot(df1[L], df1[price], data = df1)
plt.ylim(0,)
# Out:
# (0.0, 47872.20764865904)

# %%
sns.residplot(df1[L], df1[price], data = df1)
# Out:
# /home/rocko/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='length', ylabel='price'>

# %%
sns.regplot(df1[W], df1[price], data = df1)
plt.ylim(0,)
# Out:
# (0.0, 47921.7259068369)

# %%
sns.residplot(df1[W], df1[price], data = df1)
# Out:
# /home/rocko/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='width', ylabel='price'>

# %%
sns.regplot(df1[WB], df1[price], data = df1)
plt.ylim(0,)
# Out:
# (0.0, 47613.21850847956)

# %%
sns.residplot(df1[WB], df1[price], data = df1)
# Out:
# /home/rocko/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='wheel-base', ylabel='price'>

# %%
plt.figure(figsize=(12, 10))
ax1 = sns.distplot(df1[price], hist = False, color = "purple", label = "Actual values")
sns.distplot(y_hat, hist = False, color = "g", label = "Predicted values", ax = ax1)
plt.xlabel("Price")
plt.ylabel("Proportion of cars")
# Out:
# /home/rocko/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/rocko/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Proportion of cars')

# %%
X2 = df1[[ES,WB,Br]]
lmM = LinearRegression()
lmM.fit(X2,Y)
Y_hat = lmM.predict(X2)

# %%
plt.figure(figsize=(12, 10))

ax1 = sns.distplot(df1[price], hist = False, color = "purple", label = "Actual values")
sns.distplot(Y_hat, hist = False, color = "g", label = "Predicted values", ax = ax1)
plt.xlabel("Price")
plt.ylabel("Proportion of cars")

plt.show()
plt.close()
# Out:
# /home/rocko/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/rocko/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Linear: Engine Size, Wheel Base, Bore
# ## Nth order polynomial: Length, width, Highway-L/100km, City-L/100km, Horsepower, Curb weight

# %%
def PlotPolly(model,independent_variable, dependent_variable, Name, x1, x2):
    
    x_new = np.linspace(x1,x2,100)
    y_new = model(x_new)
    
    plt.plot(independent_variable, dependent_variable, ".", x_new, y_new ,"-")
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.title("Plynomial Fit")
    plt.xlabel(Name)
    plt.ylabel(price)
    
    
    plt.show()
    plt.close()

# %%
x = df1[CW]
y = df1[price]

# %%
f1 = np.polyfit(x,y,2)
p1 = np.poly1d(f1)
p1
# Out:
# poly1d([ 3.71133937e-03, -7.49260926e+00,  7.12718175e+03])

# %%
x1 = df1[CW].min()-10
x2 = df1[CW].max()+10
f2 = np.polynomial.Polynomial.fit(x,y,2)
p2 = f2.convert()
p2
# Out:
# Polynomial([ 7.12718175e+03, -7.49260926e+00,  3.71133937e-03], domain=[-1.,  1.], window=[-1.,  1.])

# %%
PlotPolly(p2,x,y,CW,x1,x2)

# %%
PlotPolly(p1,x,y,CW,x1,x2)

# %%
x3 = df1[Hp]
x1 = df1[Hp].min()-10
x2 = df1[Hp].max()+10
f = np.polynomial.Polynomial.fit(x3,y,2)
p3 = f.convert()

# %%
PlotPolly(p3,x3,y,Hp,x1,x2)

# %%
x4 = df1[CL]
x1 = df1[CL].min()-3
x2 = df1[CL].max()+2
f = np.polynomial.Polynomial.fit(x4,y,3)
p4 = f.convert()

# %%
PlotPolly(p4,x4,y,CL,x1,x2)

# %%
x5 = df1[HL]
x1 = df1[HL].min()-2
x2 = df1[HL].max()+3
f = np.polynomial.Polynomial.fit(x5,y,2)
p5 = f.convert()

# %%
PlotPolly(p5,x5,y,HL,x1,x2)

# %%
x6 = df1[L]
x1 = df1[L].min()-0.05
x2 = df1[L].max()+0.05
f = np.polynomial.Polynomial.fit(x6,y,3)
p6 = f.convert()

# %%
PlotPolly(p6,x6,y,L,x1,x2)

# %%
x7 = df1[W]
x1 = df1[W].min()-0.18
x2 = df1[W].max()+0.05
f = np.polynomial.Polynomial.fit(x7,y,3)
p7 = f.convert()

# %%
PlotPolly(p6,x6,y,W,x1,x2)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
Z = df1[[Hp,CW,L,W,HL,CL]]
y = df1[price]

# %%
pr = PolynomialFeatures(degree = 2)
print(type(pr))
pr
# Out:
# <class 'sklearn.preprocessing._data.PolynomialFeatures'>
# PolynomialFeatures()

# %%
Z_pr = pr.fit_transform(Z)
print(Z_pr[0])
#
# Out:
# [1.00000000e+00 1.11000000e+02 2.54800000e+03 8.11148486e-01
#  8.90277778e-01 1.05185185e+01 1.35238095e+01 1.23210000e+04
#  2.82828000e+05 9.00374820e+01 9.88208333e+01 1.16755556e+03
#  1.50114286e+03 6.49230400e+06 2.06680634e+03 2.26842778e+03
#  2.68011852e+04 3.44586667e+04 6.57961867e-01 7.22147472e-01
#  8.53208037e+00 1.09698176e+01 7.92594522e-01 9.36440329e+00
#  1.20399471e+01 1.10639232e+02 1.42250441e+02 1.82893424e+02]

# %%
# type(Z_pr)
print(Z.shape)
print(Z_pr.shape)
# Out:
# (201, 6)
# (201, 28)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
Input=[('Scale',StandardScaler()), ('Polynomial', PolynomialFeatures(include_bias=False)), ('Model',LinearRegression())]

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('Scale', StandardScaler()),
#                 ('Polynomial', PolynomialFeatures(include_bias=False)),
#                 ('Model', LinearRegression())])

# %%
Z = Z.astype(float)
pipe.fit(Z,y)
# Out:
# Pipeline(steps=[('Scale', StandardScaler()),
#                 ('Polynomial', PolynomialFeatures(include_bias=False)),
#                 ('Model', LinearRegression())])

# %%
y_pipe = pipe.predict(Z)

# %%
Input2 = [('Scale', StandardScaler()),('Polynomial', PolynomialFeatures(include_bias = False))]
pipe2 = Pipeline(Input2)

# %%
pipe2.fit(Z,y)
# Out:
# Pipeline(steps=[('Scale', StandardScaler()),
#                 ('Polynomial', PolynomialFeatures(include_bias=False))])

# %%
Input3 = [('Scale', StandardScaler()),('Model', LinearRegression())]
pipe3 = Pipeline(Input3)

# %%
pipe3.fit(Z,y)
ypipe = pipe3.predict(Z)

# %%
from sklearn.metrics import mean_squared_error

# %%
# Highway-L/100km Linear Regression
lm.fit(X,Y)
print("The R-square is: ", lm.score(X,Y))
# Out:
# The R-square is:  0.6417894513258818

# %%
yhat = lm.predict(X)
mse = mean_squared_error(Y,yhat)
print("The mean squared error is: ", mse)
# Out:
# The mean squared error is:  22510543.777085222

# %%
# Multiple Linear Regression (Hp,CW,Br,L,W)

X1 = df1[[Hp,CW,Br,L,W]]
lm2 = LinearRegression()
lm2.fit(X1,df1[price])
Y_hat = lm2.predict(X1)
mse_M = mean_squared_error(Y,Y_hat)
print("The R-square is: ", lm2.score(X1,Y))
print("The mean squared error is: ", mse_M)
# Out:
# The R-square is:  0.7822916598338611
# The mean squared error is:  13681152.43977606

# %%
# Multiple Lineal Regression (ES,WB,Br)

X2 = df1[[ES,WB,Br]]
lmM = LinearRegression()
lmM.fit(X2,Y)
Y_hat1 = lmM.predict(X2)
mse_M2 = mean_squared_error(Y,Y_hat1)
print("The R-square is: ", lmM.score(X2,Y))
print("The mean squared error is: ", mse_M2)
# Out:
# The R-square is:  0.7726764996856601
# The mean squared error is:  14285385.018188126

# %%
# Polynomial Regression (?)

from sklearn.metrics import r2_score

f2 = np.polynomial.Polynomial.fit(x,y,2)
p2 = f2.convert()
mse_p = mean_squared_error(df1[price],p2(x))
print("The Rsquare is: ", r2_score(y,p2(x)))
print("The mean squared values is: ", mse_p)
# Out:
# The Rsquare is:  0.7197685969900643
# The mean squared values is:  17610205.19501232
